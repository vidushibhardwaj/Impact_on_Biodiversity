# %%
## importing libraries
import pandas as pd                                    
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from numpy import cov

# %%
## csv file is read
data=pd.read_csv(r"C:\Users\Vidushi bhardwaj\Desktop\data_Analytics_project\final_dataset.csv")

# %%
data.head()
# Out:
#    year  population_growth_rate  firespots  Consumption_of_ozone_layer  \
# 0  1970                2.134819        NaN                         NaN
# 1  1971                2.134819        NaN                         NaN
# 2  1972                2.134819        NaN                         NaN
# 3  1973                2.134819        NaN                         NaN
# 4  1974                2.134819        NaN                         NaN
#
#    forest_area  sea_ice_extent_north  sea_ice_extent_south  \
# 0          NaN                   NaN                   NaN
# 1          NaN                   NaN                   NaN
# 2          NaN                   NaN                   NaN
# 3          NaN                   NaN                   NaN
# 4          NaN                   NaN                   NaN
#
#    CO2_emissions(MtCO2)  global_avg_temperature  amphibians_endangered  ...  \
# 0               14840.0                   14.04                    NaN  ...
# ...

# %%
data.shape
# Out:
# (50, 25)

# %%
data.describe()
# Out:
#              year  population_growth_rate    firespots  \
# count    50.00000               50.000000    21.000000
# mean   1994.50000                1.597596  1161.316219
# std      14.57738                0.379534   613.148313
# min    1970.00000                1.035205   553.655000
# 25%    1982.25000                1.232897   793.029100
# 50%    1994.50000                1.670245   855.679600
# 75%    2006.75000                1.934459  1444.220000
# max    2019.00000                2.134819  2823.432000
#
#        Consumption_of_ozone_layer   forest_area  sea_ice_extent_north  \
# count                2.600000e+01  2.300000e+01             36.000000
# mean                 2.852737e+05  4.078051e+06             11.746989
# std                  3.059064e+05  5.413723e+04              0.582038
# min                  6.922260e+03  3.949088e+06             10.658333
# 25%                  5.732888e+04  4.049900e+06             11.216042
# ...

# %%
## null values in dataset
data.isnull().sum()
# Out:
# year                           0
# population_growth_rate         0
# firespots                     29
# Consumption_of_ozone_layer    24
# forest_area                   27
# sea_ice_extent_north          14
# sea_ice_extent_south          14
# CO2_emissions(MtCO2)           1
# global_avg_temperature         5
# amphibians_endangered         35
# fishes_end                    35
# birds_end                     35
# mammals_end                   35
# plants_end                    35
# insects_end                   35
# reptiles_end                  35
# mollusc_end                   35
# amphibians_critically_end     35
# fishes_cri_end                35
# birds_cri_end                 35
# mammals_cri_end               35
# plants_cri_end                35
# insects_crit_end              35
# reptiles_cri_end              35
# mollusc_cri_end               35
# dtype: int64

# %%
## plotting of graphs in order to remove the null values
fig=sns.displot(data['firespots'])
plt.title("NUMBER OF FIRESPOTS AROUND THE WORLD")
plt.show(fig)
fig2=sns.displot(data['Consumption_of_ozone_layer'])
plt.title("GRAPH OF CONSUMPTION OF OZONE LAYER")
plt.show(fig2)
fig3=sns.displot(data['forest_area'])
plt.title("GRAPH OF FOREST AREA")
plt.show(fig3)

# %%
## data cleaning 
data['firespots']=data['firespots'].fillna(data['firespots'].mode()[0]) ## replacing null values by mode
data['Consumption_of_ozone_layer']=data['Consumption_of_ozone_layer'].fillna(data['Consumption_of_ozone_layer'].mode()[0]) ## replacing null values by mode
data['forest_area']=data['forest_area'].fillna(data['forest_area'].median()) ## replacing null values by median

# %%
## plotting of graphs in order to remove null values
fig=sns.displot(data['sea_ice_extent_north'])
plt.title("GRAPH OF SEA ICE EXTENT(NORTH)")
plt.show(fig)
fig2=sns.displot(data['sea_ice_extent_south'])
plt.title("GRAPH OF SEA ICE EXTENT(SOUTH)")
plt.show(fig2)

# %%
## data cleaning
data['sea_ice_extent_north']=data['sea_ice_extent_north'].fillna(data['sea_ice_extent_north'].mean()) ## replacing null values by mean
data['sea_ice_extent_south']=data['sea_ice_extent_south'].fillna(data['sea_ice_extent_south'].mean()) ## replacing null values by mean

# %%
## plotting of graphs in order to remove null values
fig=sns.displot(data['CO2_emissions(MtCO2)'])
plt.title("GRAPH OF CO2 EMISSIONS AROUND THE WORLD")
plt.show(fig)

fig2=sns.displot(data['global_avg_temperature'])
plt.title("GRAPH OF GLOBAL AVERAGE TEMPERATURE")
plt.show(fig2)

# %%
## data cleaning
data['CO2_emissions(MtCO2)']=data['CO2_emissions(MtCO2)'].fillna(data['CO2_emissions(MtCO2)'].mean()) ## repalcing null values by mean 
data['global_avg_temperature']=data['global_avg_temperature'].fillna(data['global_avg_temperature'].mean()) ## replacing null values by mean

# %%
## count of null values
data.isnull().sum()
# Out:
# year                           0
# population_growth_rate         0
# firespots                      0
# Consumption_of_ozone_layer     0
# forest_area                    0
# sea_ice_extent_north           0
# sea_ice_extent_south           0
# CO2_emissions(MtCO2)           0
# global_avg_temperature         0
# amphibians_endangered         35
# fishes_end                    35
# birds_end                     35
# mammals_end                   35
# plants_end                    35
# insects_end                   35
# reptiles_end                  35
# mollusc_end                   35
# amphibians_critically_end     35
# fishes_cri_end                35
# birds_cri_end                 35
# mammals_cri_end               35
# plants_cri_end                35
# insects_crit_end              35
# reptiles_cri_end              35
# mollusc_cri_end               35
# dtype: int64

# %%
## plotting of graphs in order to remove null values
fig=sns.displot(data['amphibians_endangered'])
plt.title("GRAPH OF ENDANGERED AMPHIBIANS AROUND THE WORLD")
plt.show(fig)
fig2=sns.displot(data['fishes_end'])
plt.title("GRAPH OF ENDANGERED FISH SPECIES AROUND THE WORLD")
plt.show(fig2)
fig3=sns.displot(data['birds_end'])
plt.title("GRAPH OF ENDANGERED BIRD SPECIES AROUND THE WORLD")
plt.show(fig3)
fig4=sns.displot(data['mammals_end'])
plt.title("GRAPH OF ENDANGERED MAMMALS AROUND THE WORLD")
plt.show(fig4)
fig5=sns.displot(data['plants_end'])
plt.title("GRAPH OF ENDANGERED PLANT SPECIES AROUND THE WORLD")
plt.show(fig5)
fig6=sns.displot(data['insects_end'])
plt.title("GRAPH OF ENDANGERED INSECT SPECIES AROUND THE WORLD")
plt.show(fig6)
fig7=sns.displot(data['reptiles_end'])
plt.title("GRAPH OF ENDANGERED REPTILES AROUND THE WORLD")
plt.show(fig7)
fig8=sns.displot(data['mollusc_end'])
plt.title("GRAPH OF ENDANGERED MOLLUSC AROUND THE WORLD")
plt.show(fig8)

# %%
## data cleaning
data['amphibians_endangered']=data['amphibians_endangered'].fillna(data['amphibians_endangered'].median()) ## replacing null values by median
data['fishes_end']=data['fishes_end'].fillna(data['fishes_end'].mean()) ## replacing null values by mean
data['birds_end']=data['birds_end'].fillna(data['birds_end'].mean()) ## replacing null values by mean
data['mammals_end']=data['mammals_end'].fillna(data['mammals_end'].mean()) ## replacing null values by mean
data['plants_end']=data['plants_end'].fillna(data['plants_end'].mean()) ## replacing null values by mean
data['insects_end']=data['insects_end'].fillna(data['insects_end'].mode()[0]) ## replacing null values by mode
data['reptiles_end']=data['reptiles_end'].fillna(data['reptiles_end'].mode()[0]) ## replacing null values by mode
data['mollusc_end']=data['mollusc_end'].fillna(data['mollusc_end'].mode()[0]) ## replacing null values by mode

# %%
data.head()
# Out:
#    year  population_growth_rate  firespots  Consumption_of_ozone_layer  \
# 0  1970                2.134819    553.655                     6922.26
# 1  1971                2.134819    553.655                     6922.26
# 2  1972                2.134819    553.655                     6922.26
# 3  1973                2.134819    553.655                     6922.26
# 4  1974                2.134819    553.655                     6922.26
#
#    forest_area  sea_ice_extent_north  sea_ice_extent_south  \
# 0   4080210.26             11.746989             12.073548
# 1   4080210.26             11.746989             12.073548
# 2   4080210.26             11.746989             12.073548
# 3   4080210.26             11.746989             12.073548
# 4   4080210.26             11.746989             12.073548
#
#    CO2_emissions(MtCO2)  global_avg_temperature  amphibians_endangered  ...  \
# 0               14840.0                   14.04                  754.0  ...
# ...

# %%
fig=sns.displot(data['amphibians_critically_end'])
plt.title("GRAPH OF CRITICALLY ENDANGERED AMPHIBIANS")
plt.show(fig)
fig2=sns.displot(data['fishes_cri_end'])
plt.title("GRAPH OF CRITICALLY ENDANGERED FISHES")
plt.show(fig2)

fig3=sns.displot(data['birds_cri_end'])
plt.title("GRAPH OF CRITICALLY ENDANGERED BIRDS")
plt.show(fig3)

fig4=sns.displot(data['mammals_cri_end'])
plt.title("GRAPH OF CRITICALLY ENDANGERED MAMMALS")
plt.show(fig4)

fig5=sns.displot(data['plants_cri_end'])
plt.title("GRAPH OF CRITICALLY ENDANGERED PLANTS")
plt.show(fig5)

fig6=sns.displot(data['reptiles_cri_end'])
plt.title("GRAPH OF CRITICALLY ENDANGERED REPTILES")
plt.show(fig6)

fig7=sns.displot(data['insects_crit_end'])
plt.title("GRAPH OF CRITICALLY ENDANGERED INSECTS")
plt.show(fig7)

fig8=sns.displot(data['mollusc_cri_end'])
plt.title("GRAPH OF CRITICALLY ENDANGERED MOLLUSC")
plt.show(fig8)

# %%
## data cleaning
data['amphibians_critically_end']=data['amphibians_critically_end'].fillna(data['amphibians_critically_end'].median()) ## replacing null values by median
data['fishes_cri_end']=data['fishes_cri_end'].fillna(data['fishes_cri_end'].mean()) ## replacing null values by mean
data['birds_cri_end']=data['birds_cri_end'].fillna(data['birds_cri_end'].mean()) ## replacing null values by mean
data['mammals_cri_end']=data['mammals_cri_end'].fillna(data['mammals_cri_end'].mean()) ## replacing null values by mean
data['plants_cri_end']=data['plants_cri_end'].fillna(data['plants_cri_end'].mean()) ## replacing null values by mean
data['reptiles_cri_end']=data['reptiles_cri_end'].fillna(data['reptiles_cri_end'].mode()[0]) ## replacing null values by mode
data['insects_crit_end']=data['insects_crit_end'].fillna(data['insects_crit_end'].mode()[0]) ## replacing null values by mode
data['mollusc_cri_end']=data['mollusc_cri_end'].fillna(data['mollusc_cri_end'].mode()[0]) ## replacing null values by mode

# %%
data.head()
# Out:
#    year  population_growth_rate  firespots  Consumption_of_ozone_layer  \
# 0  1970                2.134819    553.655                     6922.26
# 1  1971                2.134819    553.655                     6922.26
# 2  1972                2.134819    553.655                     6922.26
# 3  1973                2.134819    553.655                     6922.26
# 4  1974                2.134819    553.655                     6922.26
#
#    forest_area  sea_ice_extent_north  sea_ice_extent_south  \
# 0   4080210.26             11.746989             12.073548
# 1   4080210.26             11.746989             12.073548
# 2   4080210.26             11.746989             12.073548
# 3   4080210.26             11.746989             12.073548
# 4   4080210.26             11.746989             12.073548
#
#    CO2_emissions(MtCO2)  global_avg_temperature  amphibians_endangered  ...  \
# 0               14840.0                   14.04                  754.0  ...
# ...

# %%
## null values
data.isnull().sum().sum()
# Out:
# 0

# %%
## correlation matrix using pearson correlation method
data.corr(method="pearson")
# Out:
#                                 year  population_growth_rate  firespots  \
# year                        1.000000               -0.976884   0.436160
# population_growth_rate     -0.976884                1.000000  -0.487507
# firespots                   0.436160               -0.487507   1.000000
# Consumption_of_ozone_layer  0.001873                0.052255  -0.102231
# forest_area                -0.307574                0.327899  -0.262177
# sea_ice_extent_north       -0.570439                0.609123  -0.470369
# sea_ice_extent_south        0.361983               -0.357906   0.028754
# CO2_emissions(MtCO2)        0.948891               -0.926408   0.410791
# global_avg_temperature      0.790236               -0.796835   0.554749
# amphibians_endangered      -0.103927                0.181400  -0.371696
# fishes_end                  0.187222               -0.104496  -0.342680
# birds_end                   0.193885               -0.107891  -0.107921
# ...

# %%
## heatmap
f,ax=plt.subplots(figsize=(15,15))
sns.heatmap(data.corr(method="pearson"),annot=True)
plt.title("CORRELATION MATRIX",size=20)
plt.show()

# %% [markdown]
# # Data Analysis

# %%
## plotting graphs
fig=sns.lmplot('year','CO2_emissions(MtCO2)',data=data,fit_reg=False,height=4)
plt.title("INCREASE IN CO2 EMISSIONS WITH INCREASING TIME")
plt.show(fig)
fig2=sns.lmplot('population_growth_rate','sea_ice_extent_north',data=data,fit_reg=False,height=4)
plt.title("INCREASING SEA ICE MELTING WITH INCREASING POPULATION GROWTH")
plt.show(fig2)
fig3=sns.lmplot('CO2_emissions(MtCO2)','global_avg_temperature',data=data,fit_reg=False,height=4)
plt.title("INCREASING GLOBAL TEMPERATURE WITH INCREASING CO2 EMISSIONS")
plt.show(fig3)
fig4=sns.lmplot('plants_end','fishes_end',data=data,fit_reg=False,height=4)
plt.title("INCREASING ENDANGERED FISH SPECIES WITH INCREASING ENDANGERED PLANT SPECIES")
plt.show(fig4)
fig5=sns.lmplot('plants_end','birds_end',data=data,fit_reg=False,height=4)
plt.title("INCREASING ENDANGERED BIRD SPECIES WITH INCREASING ENDANGERED PLANT SPECIES")
plt.show(fig5)
# Out:
# c:\users\vidushi bhardwaj\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Data Preprocessing

# %%
dataset=data['CO2_emissions(MtCO2)']

# %%
dataset[40:]
# Out:
# 40    33151.00000
# 41    34272.00000
# 42    34793.00000
# 43    34959.00000
# 44    35225.00000
# 45    35239.00000
# 46    35380.00000
# 47    35811.00000
# 48    36573.00000
# 49    24680.77551
# Name: CO2_emissions(MtCO2), dtype: float64

# %%
plt.plot(dataset)

# %%
##LSTM are sensitive to the scale of the data, hence we apply MINMAX SCALER

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
dataset=scaler.fit_transform(np.array(dataset).reshape(-1,1))

# %%
dataset.shape
# Out:
# (50, 1)

# %%
## splitting the data into training and test data
train_size=int(len(dataset)*0.65)
test_size=len(dataset)-train_size
train_data,test_data=dataset[0:train_size,:],dataset[train_size:len(dataset),:1]

# %%
train_size,test_size
# Out:
# (32, 18)

# %%
## function to split the data
def create_dataset(data,time_step):
    x,y=[],[]
    for i in range(len(data)-time_step-1):
        a=data[i:(i+time_step),0]
        x.append(a)
        y.append(data[i+time_step,0])
    return np.array(x),np.array(y)

# %%
time_step=5
x_train, y_train= create_dataset(train_data, time_step)
x_test, y_test= create_dataset(test_data, time_step)

# %%
print(x_train.shape,y_train.shape)
# Out:
# (26, 5) (26,)

# %%
print(x_test.shape,y_test.shape)
# Out:
# (12, 5) (12,)

# %%
## reshaping the inputs which is required for LSTM
x_train = x_train.reshape(x_train.shape[0],x_train.shape[1],1)
x_test = x_test.reshape(x_test.shape[0],x_test.shape[1],1)

# %% [markdown]
# # Building LSTM Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(5,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(optimizer="adam",loss='mean_squared_error')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm (LSTM)                  (None, 5, 50)             10400
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 5, 50)             20200
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 51
# ...
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train,y_train,validation_data=(x_test,y_test),epochs=100,verbose=1)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.0982 - val_loss: 0.7580
# Epoch 2/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0898 - val_loss: 0.7187
# Epoch 3/100
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0816 - val_loss: 0.6784
# Epoch 4/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0734 - val_loss: 0.6363
# Epoch 5/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0651 - val_loss: 0.5920
# Epoch 6/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0567 - val_loss: 0.5452
# Epoch 7/100
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0483 - val_loss: 0.4955
# Epoch 8/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0399 - val_loss: 0.4427
# Epoch 9/100
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0316 - val_loss: 0.3871
# Epoch 10/100
# ...

# %% [markdown]
# # Prediction

# %%
train_predict=model.predict(x_train)
test_predict=model.predict(x_test)

# %%
## scaled data is transformed
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %% [markdown]
# # Calculating Performance Metrics

# %%
import math
from sklearn.metrics import mean_squared_error
math.sqrt(mean_squared_error(y_train,train_predict))  ## train data RMSE
# Out:
# 21332.86631023207

# %%
math.sqrt(mean_squared_error(y_test,test_predict))   ## test data RMSE
# Out:
# 34561.689051612164

# %% [markdown]
# # Plotting

# %%
time_step=5
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[: , :] = np.nan
trainPredictPlot[time_step:len(train_predict)+time_step, :] = train_predict

testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(train_predict)+(time_step*2)+1:len(dataset)-1, :] = test_predict

plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.title("GRAPH SHOWING RESULTS OF THE MODEL ON TRAINING DATA")
plt.legend(labels=['dataset','x train','x test'])
plt.show()

# %%
len(test_data)
# Out:
# 18

# %%
x_input=test_data[13:].reshape(1,-1)           ## last 5 datas are stored in x_input
x_input.shape
# Out:
# (1, 5)

# %%
temp_input=list(x_input)
temp_input=temp_input[0].tolist()
temp_input
# Out:
# [0.9386186904707128,
#  0.945106520038651,
#  0.9649381125477385,
#  1.0,
#  0.4528033640180409]

# %% [markdown]
# # Prediction for next 10 years

# %%
lst_output=[]
n_steps=5
i=0
while(i<10):
    
    if(len(temp_input)>5):
        #print(temp_input)
        x_input=np.array(temp_input[1:])
        print(str(i)+" day input "+str(x_input))
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        #print(x_input)
        yhat = model.predict(x_input, verbose=0)
        print(str(i)+" day output "+str(yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        #print(temp_input)
        lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input = x_input.reshape((1, n_steps,1))
        yhat = model.predict(x_input, verbose=0)
        print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        print(len(temp_input))
        lst_output.extend(yhat.tolist())
        i=i+1
    

print(lst_output)
# Out:
# [1.0798455]
# 6
# 1 day input [0.94510652 0.96493811 1.         0.45280336 1.07984555]
# 1 day output [[1.0562991]]
# 2 day input [0.96493811 1.         0.45280336 1.07984555 1.05629909]
# 2 day output [[1.0290291]]
# 3 day input [1.         0.45280336 1.07984555 1.05629909 1.02902913]
# 3 day output [[0.9977226]]
# 4 day input [0.45280336 1.07984555 1.05629909 1.02902913 0.99772263]
# 4 day output [[0.9583714]]
# 5 day input [1.07984555 1.05629909 1.02902913 0.99772263 0.9583714 ]
# 5 day output [[1.2232049]]
# 6 day input [1.05629909 1.02902913 0.99772263 0.9583714  1.22320485]
# 6 day output [[1.2032417]]
# 7 day input [1.02902913 0.99772263 0.9583714  1.22320485 1.20324171]
# 7 day output [[1.2039154]]
# 8 day input [0.99772263 0.9583714  1.22320485 1.20324171 1.20391536]
# 8 day output [[1.235165]]
# 9 day input [0.9583714  1.22320485 1.20324171 1.20391536 1.235165  ]
# 9 day output [[1.3051225]]
# ...

# %%
day_new=np.arange(1,6)
day_predict=np.arange(6,16)

# %% [markdown]
# # Plotting the prediction for next 10 years

# %%
len(dataset)
# Out:
# 50

# %%
plt.plot(day_new,scaler.inverse_transform(dataset[45:]))
plt.plot(day_predict,scaler.inverse_transform(lst_output))
plt.title("GRAPH SHOWING PREDICTION FOR NEXT 10 YEARS")
plt.legend(labels=['dataset','next 10 years'])

# %%
df=dataset.tolist()
df.extend(lst_output)
plt.plot(df[20:])
plt.title("PREDICTED GRAPH MERGED WITH ORIGINAL")
# Out:
# Text(0.5, 1.0, 'PREDICTED GRAPH MERGED WITH ORIGINAL')

# %%
df=scaler.inverse_transform(df).tolist()
plt.plot(df)
plt.title("GRAPH ALTOGETHER 1970-2030")
# Out:
# Text(0.5, 1.0, 'GRAPH ALTOGETHER 1970-2030')
